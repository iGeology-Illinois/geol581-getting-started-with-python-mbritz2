# %%
# !pip install mplstereonet
# !pip install pandas
import numpy as np
import matplotlib.pyplot as plt
import mplstereonet
from IPython.display import HTML, YouTubeVideo

# %%
# HELPER FUNCTIONS
def plot_planes(planes, title="Planes on Schmidt Net"):
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='equal_area')
    
    for strike, dip in planes:
        ax.plane(strike, dip, linewidth=2)
        pt, pp = mplstereonet.pole(strike, dip)
        ax.pole(strike, dip, 'o', markersize=8)
        
    ax.grid(True)
    ax.set_title(title)
    plt.show()

def plot_poles(poles, title="Poles on Schmidt Net"):
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='equal_area')
    
    for (trend, plunge) in poles:
        ax.line(trend, plunge, marker='o', markersize=8)
        
    ax.grid(True)
    ax.set_title(title)
    plt.show()

print("Helper functions defined: plot_planes() and plot_poles()")
# Out:
# Helper functions defined: plot_planes() and plot_poles()

# %%
import pandas as pd

df = pd.read_csv('strikes and dips.csv')  # Load CSV into a DataFrame
print(df)  # Display the data
# Out:
#        ID  Strike   Dip              Date    MeasuredBy  \
# 0    P1-3    43.3  51.0  2025-01-03 23:24   Carlos Diaz
# 1    P2-4   133.5  80.0  2025-01-12 17:55    John Smith
# 2    P4-1   119.4  87.8  2025-01-16 02:19   Carlos Diaz
# 3    P1-7    43.2  49.4  2025-01-10 19:48  Sarah Parker
# 4    P1-2    44.2  50.6  2025-01-15 22:05      Mei Chen
# 5    P3-9   226.6  41.4  2025-01-13 01:42   Carlos Diaz
# 6    P3-6   226.1  38.1  2025-01-14 15:10      Mei Chen
# 7    P2-7   136.1  79.3  2025-01-26 22:19      Mei Chen
# 8   P1-10    43.1  51.3  2025-01-30 22:38   Carlos Diaz
# 9    P2-9   136.8  81.6  2025-01-24 06:09    John Smith
# 10  P3-10   226.4  41.6  2025-01-16 20:34   Carlos Diaz
# 11   P2-5   133.2  78.3  2025-01-26 16:34   Carlos Diaz
# 12   P1-4    45.4  48.4  2025-01-15 08:16  Sarah Parker
# 13   P4-2   351.7  82.2  2025-01-08 05:35   Carlos Diaz
# 14   P2-8   136.7  79.5  2025-01-04 08:47  Sarah Parker
# 15   P3-4   225.0  41.6  2025-01-04 11:29    John Smith
# 16   P2-1   136.0  79.8  2025-01-29 14:31    John Smith
# 17   P3-5   225.1  40.9  2025-01-27 11:43    John Smith
# 18   P1-6    46.9  50.9  2025-01-17 13:00    John Smith
# 19   P3-2   226.5  39.0  2025-01-02 11:47   Carlos Diaz
# 20   P3-7   224.6  39.3  2025-01-07 13:26   Carlos Diaz
# 21   P1-1    46.7  51.9  2025-01-05 22:58   Carlos Diaz
# 22   P1-9    45.8  48.8  2025-01-18 22:54    John Smith
# 23   P2-2   133.9  80.4  2025-01-30 11:15  Sarah Parker
# 24  P2-10   136.9  78.4  2025-01-22 16:02      Mei Chen
# 25   P3-1   225.5  41.6  2025-01-11 07:39      Mei Chen
# 26   P2-3   133.1  80.9  2025-01-11 15:30    John Smith
# 27   P3-8   226.0  41.6  2025-01-05 12:10   Carlos Diaz
# 28   P4-3   185.8  70.7  2025-01-08 05:07  Sarah Parker
# 29   P3-3   225.9  38.9  2025-01-10 12:36   Carlos Diaz
# 30   P1-8    46.0  50.7  2025-01-03 08:12  Sarah Parker
# 31   P2-6   134.7  80.2  2025-01-16 01:40  Sarah Parker
# 32   P1-5    44.2  49.7  2025-01-08 04:09  Sarah Parker
#
#                      Company Location                    Notes
# 0   Pettijohn and Associates   Site C     Inconsistent bedding
# 1   Pettijohn and Associates   Site D        Uncertain contact
# 2   Pettijohn and Associates   Site C         Possible error??
# 3   Pettijohn and Associates   Site C              Loose scree
# 4   Pettijohn and Associates   Site B       Watch for slippage
# 5   Pettijohn and Associates   Site A       Watch for slippage
# 6   Pettijohn and Associates   Site B     Inconsistent bedding
# 7   Pettijohn and Associates   Site B     Inconsistent bedding
# 8   Pettijohn and Associates   Site B         Difficult to see
# 9   Pettijohn and Associates   Site C       Watch for slippage
# 10  Pettijohn and Associates   Site B              Wet outcrop
# 11  Pettijohn and Associates   Site A  Covered with vegetation
# 12  Pettijohn and Associates   Site A              Wet outcrop
# 13  Pettijohn and Associates   Site D         Possible error??
# 14  Pettijohn and Associates   Site B  Covered with vegetation
# 15  Pettijohn and Associates   Site C       Watch for slippage
# 16  Pettijohn and Associates   Site B         Difficult to see
# 17  Pettijohn and Associates   Site A              Loose scree
# 18  Pettijohn and Associates   Site D        Uncertain contact
# 19  Pettijohn and Associates   Site D              Loose scree
# 20  Pettijohn and Associates   Site C     Inconsistent bedding
# 21  Pettijohn and Associates   Site C              Loose scree
# 22  Pettijohn and Associates   Site A        Uncertain contact
# 23  Pettijohn and Associates   Site C  Covered with vegetation
# 24  Pettijohn and Associates   Site B           Measure again?
# 25  Pettijohn and Associates   Site A              Wet outcrop
# 26  Pettijohn and Associates   Site B              Loose scree
# 27  Pettijohn and Associates   Site D           Measure again?
# 28  Pettijohn and Associates   Site B         Possible error??
# 29  Pettijohn and Associates   Site B              Loose scree
# 30  Pettijohn and Associates   Site D              Loose scree
# 31  Pettijohn and Associates   Site A         Difficult to see
# 32  Pettijohn and Associates   Site D     Inconsistent bedding

# %%
# Extract strike and dip values
strike = df["Strike"].values
dip = df["Dip"].values

# Create a Schmidt net plot
fig, ax = mplstereonet.subplots(figsize=(8, 8), projection= 'equal_area')

# Convert strike and dip into poles and plot them
ax.pole(strike, dip, 'ko', markersize=5, label="Poles")

# Add density contours to observe clustering
ax.density_contourf(strike, dip, measurement='poles', cmap='Blues')
ax.density_contour(strike, dip, measurement='poles', colors='black')

# Labels and display
ax.grid()
ax.legend()
plt.title("Schmidt Net of Bedding Planes (Poles)")
plt.show()

# %% [markdown]
# Three outliers are identified outside the three main bedding planes. When looking at the raw data, there are three points with potenital data error comments. These points are removed from the dataset and the analysis is rerun.

# %%
# Drop the outliers
outlier_ids = ["P4-1","P4-2", "P4-3"]  # IDs of detected outliers
cleaned_df = df[~df["ID"].isin(outlier_ids)]

# Display the cleaned DataFrame
print(cleaned_df)
# Out:
#        ID  Strike   Dip              Date    MeasuredBy  \
# 0    P1-3    43.3  51.0  2025-01-03 23:24   Carlos Diaz
# 1    P2-4   133.5  80.0  2025-01-12 17:55    John Smith
# 3    P1-7    43.2  49.4  2025-01-10 19:48  Sarah Parker
# 4    P1-2    44.2  50.6  2025-01-15 22:05      Mei Chen
# 5    P3-9   226.6  41.4  2025-01-13 01:42   Carlos Diaz
# 6    P3-6   226.1  38.1  2025-01-14 15:10      Mei Chen
# 7    P2-7   136.1  79.3  2025-01-26 22:19      Mei Chen
# 8   P1-10    43.1  51.3  2025-01-30 22:38   Carlos Diaz
# 9    P2-9   136.8  81.6  2025-01-24 06:09    John Smith
# 10  P3-10   226.4  41.6  2025-01-16 20:34   Carlos Diaz
# 11   P2-5   133.2  78.3  2025-01-26 16:34   Carlos Diaz
# 12   P1-4    45.4  48.4  2025-01-15 08:16  Sarah Parker
# 14   P2-8   136.7  79.5  2025-01-04 08:47  Sarah Parker
# 15   P3-4   225.0  41.6  2025-01-04 11:29    John Smith
# 16   P2-1   136.0  79.8  2025-01-29 14:31    John Smith
# 17   P3-5   225.1  40.9  2025-01-27 11:43    John Smith
# 18   P1-6    46.9  50.9  2025-01-17 13:00    John Smith
# 19   P3-2   226.5  39.0  2025-01-02 11:47   Carlos Diaz
# 20   P3-7   224.6  39.3  2025-01-07 13:26   Carlos Diaz
# 21   P1-1    46.7  51.9  2025-01-05 22:58   Carlos Diaz
# 22   P1-9    45.8  48.8  2025-01-18 22:54    John Smith
# 23   P2-2   133.9  80.4  2025-01-30 11:15  Sarah Parker
# 24  P2-10   136.9  78.4  2025-01-22 16:02      Mei Chen
# 25   P3-1   225.5  41.6  2025-01-11 07:39      Mei Chen
# 26   P2-3   133.1  80.9  2025-01-11 15:30    John Smith
# 27   P3-8   226.0  41.6  2025-01-05 12:10   Carlos Diaz
# 29   P3-3   225.9  38.9  2025-01-10 12:36   Carlos Diaz
# 30   P1-8    46.0  50.7  2025-01-03 08:12  Sarah Parker
# 31   P2-6   134.7  80.2  2025-01-16 01:40  Sarah Parker
# 32   P1-5    44.2  49.7  2025-01-08 04:09  Sarah Parker
#
#                      Company Location                    Notes
# 0   Pettijohn and Associates   Site C     Inconsistent bedding
# 1   Pettijohn and Associates   Site D        Uncertain contact
# 3   Pettijohn and Associates   Site C              Loose scree
# 4   Pettijohn and Associates   Site B       Watch for slippage
# 5   Pettijohn and Associates   Site A       Watch for slippage
# 6   Pettijohn and Associates   Site B     Inconsistent bedding
# 7   Pettijohn and Associates   Site B     Inconsistent bedding
# 8   Pettijohn and Associates   Site B         Difficult to see
# 9   Pettijohn and Associates   Site C       Watch for slippage
# 10  Pettijohn and Associates   Site B              Wet outcrop
# 11  Pettijohn and Associates   Site A  Covered with vegetation
# 12  Pettijohn and Associates   Site A              Wet outcrop
# 14  Pettijohn and Associates   Site B  Covered with vegetation
# 15  Pettijohn and Associates   Site C       Watch for slippage
# 16  Pettijohn and Associates   Site B         Difficult to see
# 17  Pettijohn and Associates   Site A              Loose scree
# 18  Pettijohn and Associates   Site D        Uncertain contact
# 19  Pettijohn and Associates   Site D              Loose scree
# 20  Pettijohn and Associates   Site C     Inconsistent bedding
# 21  Pettijohn and Associates   Site C              Loose scree
# 22  Pettijohn and Associates   Site A        Uncertain contact
# 23  Pettijohn and Associates   Site C  Covered with vegetation
# 24  Pettijohn and Associates   Site B           Measure again?
# 25  Pettijohn and Associates   Site A              Wet outcrop
# 26  Pettijohn and Associates   Site B              Loose scree
# 27  Pettijohn and Associates   Site D           Measure again?
# 29  Pettijohn and Associates   Site B              Loose scree
# 30  Pettijohn and Associates   Site D              Loose scree
# 31  Pettijohn and Associates   Site A         Difficult to see
# 32  Pettijohn and Associates   Site D     Inconsistent bedding

# %%
# Extract strike and dip values
strike = cleaned_df["Strike"].values
dip = cleaned_df["Dip"].values

# Create a Schmidt net plot
fig, ax = mplstereonet.subplots(figsize=(8, 8), projection= 'equal_area')

# Convert strike and dip into poles and plot them
ax.pole(strike, dip, 'ko', markersize=5, label="Poles")

# Add density contours to observe clustering
ax.density_contourf(strike, dip, measurement='poles', cmap='Blues')
ax.density_contour(strike, dip, measurement='poles', colors='black')

# Labels and display
ax.grid()
ax.legend()
plt.title("Schmidt Net of Bedding Planes (Poles)")
plt.show()

# %% [markdown]
# 1. Presence of Distinct Bedding Plane Clusters
# 	•	The stereonet shows multiple high-density clusters of poles, which correspond to different sets of bedding planes.
# 	•	These clusters suggest that the bedding planes belong to at least three distinct structural orientations.
#
# 2. Potential Fold or Structural Domains
# 	•	If the poles form three distinct clusters, it could indicate the presence of multiple fold axes or structural blocks.
# 	•	The spacing and orientation of the clusters can provide insights into whether the area has undergone folding or faulting.
#
# 3. Density Contours Indicate Major Structural Trends
# 	•	The blue shaded density contours highlight regions of high pole concentration, meaning that most bedding planes fall within these orientations.
# 	•	The symmetry of the pole distribution could indicate the dominant stress regime that affected the rock formations.
#
# 4. Interpretation of Geological Deformation
# 	•	If the poles are evenly spaced around a great circle, it could indicate a cylindrical fold.
# 	•	If there is one dominant cluster, it would suggest a relatively uniform bedding orientation.
# 	•	Since we see multiple clusters, this suggests at least three major bedding orientations, which could be due to tectonic deformation, fault blocks, or different stratigraphic units.

# %% [markdown]
# When K-Means clustering is preformed, 3 bedding planes are identified.
#
# 	1.	Bedding Plane 1 (Strike: 135.1°, Dip: 79.8°) (Lower Right)
# 	    •	This is a steeply dipping plane, nearly vertical.
# 	    •	It suggests the presence of a highly folded or faulted structure.
# 	    •	If exposed in a cut slope, toppling failure could be a concern.
#
# 	2.	Bedding Plane 2 (Strike: 225.8°, Dip: 40.4°) (Left Side)
# 	    •	This plane dips at a moderate angle (~40°).
# 	    •	It may be associated with regional bedding orientation or a significant structural feature.
# 	    •	If aligned with a slope, planar sliding could occur.
#
# 	3.	Bedding Plane 3 (Strike: 44.9°, Dip: 50.3°) (Top Right)
# 	    •	This plane has a moderate dip (~50°).
# 	    •	It may indicate an alternative bedding set or a conjugate structure.
# 	    •	If intersecting another plane, it could contribute to wedge failures.
#
#
# 		Engineering & Stability Considerations
#
# 	1.	Cut Slope Stability
# 		•	If the slope strike aligns with any of these bedding planes, failures could be possible.
# 		•	Steeply dipping planes (~79.8°) suggest potential toppling risks.
# 		•	Moderately dipping planes (~40–50°) indicate potential sliding failure.
#
# 	2.	Tunnel Design & Portal Stability
# 		•	A tunnel entrance should be perpendicular to the dominant bedding strike to avoid slab failures.
# 		•	If tunnels cut through the steeply dipping bedding, additional reinforcement (bolts, shotcrete) may be needed.
#
# 	3.	Rockfall & Wedge Failure Risk
# 		•	The combination of Bedding Plane 2 & Bedding Plane 3 could lead to wedge failure, depending on joint sets.
# 		•	Rock bolts should be placed perpendicular to bedding planes to maximize support.

# %%
# !pip install scikit-learn
from sklearn.cluster import KMeans

# Prepare data for clustering
data = np.column_stack((cleaned_df["Strike"].values, cleaned_df["Dip"].values))

# Use KMeans clustering to identify 3 bedding plane sets
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
cleaned_df["Cluster"] = kmeans.fit_predict(data)

# Compute mean strike and dip for each cluster
bedding_sets = cleaned_df.groupby("Cluster")[["Strike", "Dip"]].mean().reset_index()
planes = list(zip(bedding_sets["Strike"], bedding_sets["Dip"]))

# Convert all strike/dip pairs into poles
poles = [mplstereonet.pole(strike, dip) for strike, dip in zip(cleaned_df["Strike"], cleaned_df["Dip"])]

# Function to plot great circles for bedding planes
def plot_planes(planes, title="Planes on Stereonet"):
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='stereonet')
    
    for strike, dip in planes:
        ax.plane(strike, dip, linewidth=2, label=f"Plane {strike:.1f}/{dip:.1f}")
        pt, pp = mplstereonet.pole(strike, dip)
        ax.pole(strike, dip, 'o', markersize=8, label="Pole")

    ax.grid(True)
    ax.legend()
    ax.set_title(title)
    plt.show()

# Function to plot poles
def plot_poles(poles, title="Poles on Stereonet"):
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='stereonet')

    for (trend, plunge) in poles:
        ax.line(trend, plunge, marker='o', markersize=8)
        
    ax.grid(True)
    ax.set_title(title)
    plt.show()

# Plot the stereonets
plot_planes(planes, title="Bedding Planes on Stereonet")
# Out:
# Requirement already satisfied: scikit-learn in /Users/matthewbritz/miniforge3/envs/geo_env/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/matthewbritz/miniforge3/envs/geo_env/lib/python3.10/site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/matthewbritz/miniforge3/envs/geo_env/lib/python3.10/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/matthewbritz/miniforge3/envs/geo_env/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/matthewbritz/miniforge3/envs/geo_env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# /var/folders/l1/p4q6kqx57rnbr4sdmlxhm7_m0000gn/T/ipykernel_38398/1853883563.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["Cluster"] = kmeans.fit_predict(data)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplstereonet

# Load dataset (replace with your actual file path)
file_path = "strikes and dips.csv"  
df = pd.read_csv(file_path)

# Drop the specified outliers
outlier_ids = ["P4-1", "P4-2", "P4-3"]
cleaned_df = df[~df["ID"].isin(outlier_ids)]

# Extract strike and dip values
strike = cleaned_df["Strike"].values
dip = cleaned_df["Dip"].values

# Function to plot all bedding planes (great circles) and poles on a Stereonet
def plot_bedding_planes_and_poles(strike, dip, title="Stereonet with Bedding Planes and Poles"):
    fig, ax = mplstereonet.subplots(figsize=(8, 8))  # Equal-Angle Projection

    # Plot great circles for all bedding planes
    for s, d in zip(strike, dip):
        ax.plane(s, d, linewidth=1, color="gray", alpha=0.7)

    # Plot poles for all bedding planes
    ax.pole(strike, dip, 'ko', markersize=5, label="Poles")

    # Improve plot aesthetics
    ax.grid(True)
    ax.legend()
    ax.set_title(title)

    # Show plot
    plt.show()

# Generate the stereonet with all bedding planes and poles
plot_bedding_planes_and_poles(strike, dip, title="Stereonet with Bedding Planes and Poles")
